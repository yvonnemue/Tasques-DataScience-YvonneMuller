# %% [markdown]
# # Sprint 14 Tasca 1. Tasca base de dades NoSQL

# %% [markdown]
# ## Nivell 1

# %% [markdown]
# ## Exercici 1. Descarrega't Kibana i mostra algunes gràfiques utilitzant conjunts de dades d'Exemple.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math

# %%
Image("Cap0.png")

# %% [markdown]
# En la captura anterior podem veure com amb el conjunt de dades d'exemple de vols hem creat diversos gràfics i visualitzacions com **mètriques** per saber el nombre de vols efectuats durant la setmana, així com el nombre i percentatge de vols cancel·lats i de vols endarrerits.
#
# Mitjançant un **gràfic de barres** o histograma podem veure l'evolució del nombre de vols segons el dia, amb un **gràfic d'àrea de percentatge** podem observar el percentatge de vols que no han patit cap endarreriment i el percentatge de vols amb endarreriment segons la causa (seguretat, temps, etc.).
#
# Amb un **gràfic de barres horitzontal stacked** podem veure el nombre de vols i de cancel·lacions per ciutat de les 10 ciutats amb més vols, amb un **heatmap** podem veure el percentatge que representa cada tipus d'endarreriment respecte del total d'endarreriments, i amb un **núvol de paraules** podem veure quin es el tipus de temps més habitual a les ciutats d'origen.

# %% [markdown]
# ## Nivell 2

# %% [markdown]
# ## Exercici 1. Implementa un dashboard que visualitzi interactivament les dades que triïs.

# %% [markdown]
# El següent dashbord inclou el que es demana tant en l'exercici del nivell 2 (visualitzar interactivament les dades) com en el del nivell 3 (incorporar gràfics de tots els tipus).
#
# Com que Kibana no permet generar un enllaç per consultar el Dashboard sense una compta i l'exportació amb PDF no m'ha funcionat, he generat captures de pantalla per mostrar el dashboard detalladament.

# %%
Image("Cap1_filtre1.png")

# %% [markdown]
# Com podem veure en les captures anteriors, gràcies a la implementació d'un filtre, el dashboard permet visualitzar les dades de manera interactiva. La imatge de la dreta mostra el dashboard sense cap filtre, mentre que la de l'esquerra mostra les dades només del dilluns. D'aquesta manera podem veure, per exemple, dels 77 mil dòlars d'ingressos de la setmana quants corresponen al dilluns, o que del total de 1040 transaccions només 143 es realitzen en dilluns.
#
# El filtre també permet filtrar les dades per fabricant, categoria de producte i producte.

# %%
Image("Cap1_filtre2.png")

# %% [markdown]
# En aquestes captures s'ha filtrat per fabricant **Low Tide Media** a l'esquerra i per categoria **Women's accessories** a la dreta.

# %%
Image("Cap1_filtre3.png")

# %% [markdown]
# El filtre fins i tot permet filtrar per més d'una cosa alhora, com es mostra en la captura anterior on hem filtrat tant per fabricant com per categoria.

# %% [markdown]
# ## Nivell 3

# %% [markdown]
# ## Exercici 1. Implementa un dashboard que generi gràfics utilitzant cadascun dels diferents tipus de gràfics que ofereix Kibana.

# %%
from IPython.display import Image
from IPython.core.display import HTML 
# Inici del dashboard
Image("Cap1.png")

# %% [markdown]
# En aquesta primera part del Dashboard trobem el títol i una petita descripció. A la dreta trobem els filtres mitjançant els quals podem manipular el dashboard de manera interactiva. Just a sota de la descripció hi ha 6 **mètriques** que ens donen una visió general de com han anat les operacions del període seleccionat (els 7 últims dies per defecte).
#
# Una línia més avall hi trobem un **gràfic de barres horitzontal** que mostra els 3 articles més venuts i la quantitat de cadascun d'ells, i, a la dreta, un **gràfic de barres vertical** amb els 4 fabricants dels quals s'han venut més productes.
#
# A la línia de sota hi trobem un **gràfic de barres horitzontal stacked** amb els 3 productes més venuts per gènere i un **dònut** que ens mostra el percentatge de transaccions que ha realitzat cada gènere.

# %%
Image("Cap2.png")

# %% [markdown]
# En aquesta segona imatge tenim la continuació del dashboard amb un **gràfic de barres vertical de percentatge** que mostra les categories més venudes cada dia del període. Just a sota hi ha un **gràfic lineal** amb el nombre d'articles venuts (verd) i de transaccions (roig) el període actual comparat amb el període anterior. A la dreta hi trobem un **Treemap** amb les categories preferides de manera agregada. A la línia inferior hi ha un **gràfic d'àrea stacked** amb els ingressos que genera cada fabricant cada dia del període.

# %%
Image("Cap3.png")

# %% [markdown]
# En aquestes dues línies hi trobem un **gràfic d'àrea de percentatge** amb el percentatge d'ingresos que genera cada categoria cada dia del període (s'han creat filtres per unificar les categories d'accesoris, sabates i roba d'home i de dona en una sola per a cada tipus que englobi els accessoris d'home i de dona, una altra per a les sabates d'home i de dona i, finalment, una que englobi la roba, tant d'home com de dona). També hi ha un **gràfic vertical stacked** que compara els ingressos que generen les vendes de packs versus d'articles que no son packs (s'han creat filtres pel nom de l'article per comprar els articles que son packs dels que no ho son). A la dreta de tot hi trobem un **gràfic d'area** amb el percentatge que s'ha aconseguit cada dia dels ingresos marcats com a objectiu (en aquest cas 8 mil dòlars a la setmana).
#
# A la línia de sota hi trobem un **heatmap** amb els ingressos dels 10 productes més venuts. Com més proper al color roig fosc, més ingressos i com més proper al color blau fosc, menys ingressos generen els productes.

# %%
Image("Cap4.png")

# %% [markdown]
# Les següents línies del dashboard inclouen una **taula** amb una comparació diària dels ingressos i les transaccions d'aquesta setmana versus el mateix dia de la setmana anterior. La diferència entre aquest períodes es mostra a nivell absolut i percentual. També hi trobem un **gràfic de barres horitzontal de percentatge** amb els ingressos que genera cada país i un **gràfic pie** amb el percentatge de transaccions que es realitzen a cada país.

# %%
Image("Cap5.png")

# %% [markdown]
# Finalment, com que el conjunt de dades inclou dades geoespacials, hi trobem un **mapa** amb el nombre de comandes realitzades en cada país i una **taula** per explorar les diferents entrades del conjunt de dades.
