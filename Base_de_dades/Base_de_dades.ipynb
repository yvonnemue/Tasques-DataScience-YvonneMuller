# %% [markdown]
# # Sprint 13 Tasca 1. Bases de dades relacionals

# %% [markdown]
# ## Nivell 1

# %% [markdown]
# ## Exercici 1. Crea una base relacional d’exemple utilitzant un document de text o a mà.
#
# Dissenya-la perquè contingui les següents taules, i estableix les relacions que consideris necessàries entre elles:
#
# -	Taula de compres (transaccions)
#
# -	Taula d’establiments
#
# -	Taula de treballadors
#
# -	Taula de clients
#
# -	Taula de productes
#
# -	Taula de tipus de productes
#
# Defineix les propietats de les relacions (1:1, 1:n, n:n), i crea algunes de les variables que podrien contenir, per exemple:
#
#
#
# Taula d’establiments
#
# -	IDestabliment (unique key)
#
# -	Nom
#
# -	Localització
#
# -	Superfície

# %%
import pandas as pd
import numpy as np
import warnings

from IPython.display import Image
from IPython.core.display import HTML 
Image("fig1.jpg")

# %% [markdown]
# ## Nivell 2

# %% [markdown]
# ## Exercici 2. Utilitza un programa de creació de diagrames entitat-relació com http://dia-installer.de per crear el diagrama.

# %%
# Esquema de l'exercici 1 creat amb Lucid.app (https://lucid.app/)
Image("fig2.png")

# %% [markdown]
# ## Nivell 3

# %% [markdown]
# ## Exercici 3. Utilitza el Workbench de MySQL per crear un model relacional.

# %%
# Esquema de l'exercici 1 creat amb MYSQL Workbench
Image("fig3.png")
